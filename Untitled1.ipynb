# %%
import numpy as np
import pandas as pd
import itertools
import seaborn as sns
import matplotlib.pyplot as plt
from joypy import joyplot
sns.set_theme(style="whitegrid")

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.calibration import CalibratedClassifierCV

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score





users = pd.read_csv("users2.csv")
users_cresci = pd.read_csv("users_cresci.csv")
users_total = users.append(users_cresci, ignore_index=True)


X = users_total[["dataset","label","statuses_count","followers_count","friends_count","favourites_count", \
            "listed_count","default_profile","geo_enabled","profile_use_background_image","verified","protected"]].fillna(0)

X_indomain = X[X["dataset"].isin(["fake_followers.csv","genuine_accounts.csv","social_spambots_1.csv","social_spambots_2.csv",
                                  "social_spambots_3.csv","traditional_spambots_1.csv","traditional_spambots_2.csv","traditional_spambots_3.csv"])].copy()

X_train, X_test, y_train, y_test = train_test_split(X_indomain.drop(["dataset","label"], axis=1), X_indomain["label"], test_size=0.25, random_state=42)

# %%
gp = X_indomain.groupby("label")

for label,label_data in gp:
    print(f"{label} -------- {len(label_data)}")
# Out:
# bot -------- 9766
# human -------- 3474

# %%
X_outdomain = X[~X["dataset"].isin(["fake_followers.csv","genuine_accounts.csv","social_spambots_1.csv","social_spambots_2.csv",
                                  "social_spambots_3.csv","traditional_spambots_1.csv","traditional_spambots_2.csv","traditional_spambots_3.csv"])].copy()

# %%
gp = X_outdomain.groupby("label")

for label,label_data in gp:
    print(f"{label} -------- {len(label_data)}")
# Out:
# bot -------- 16954
# human -------- 25237

# %%
3474/(3474+9766)
# Out:
# 0.26238670694864047

# %%
16954/(16954+25237)
# Out:
# 0.4018392548173781

# %%
len(X_indomain)/len(X)
# Out:
# 0.2388555140625282

# %%
gp = X.groupby("dataset")

for label,label_data in gp:
    print(f"{label},{len(label_data)}")
# Out:
# E13_users.csv,1481
# FSF_users.csv,1169
# INT_users.csv,1337
# TFP_users.csv,469
# TWT_users.csv,845
# botometer-feedback-2019.tsv,461
# botwiki-2019.tsv,654
# celebrity-2019.tsv,5793
# cresci-rtbust-2019.tsv,653
# cresci-stock-2018.tsv,13161
# fake_followers.csv,3351
# genuine_accounts.csv,3474
# gilani-2017.tsv,2491
# midterm-2018.tsv,7729
# pronbots.tsv,1876
# social_spambots_1.csv,991
# social_spambots_2.csv,3457
# social_spambots_3.csv,464
# traditional_spambots_1.csv,1000
# traditional_spambots_2.csv,100
# traditional_spambots_3.csv,403
# traditional_spambots_4.csv,1128
# varol-2017.new3,2208
# vendor-purchased-2019.tsv,736

# %%
def get_valid_combinations(users_total,max_datasets_num=8):

    datasets = users_total["dataset"].unique()

    total_len = len(users_total)
    total_len_bot = len(users_total[users_total["label"]=='bot'])
    total_len_human = len(users_total[users_total["label"]=='human'])

    lengths = dict()
    lengths_bot = dict()
    lengths_human = dict()
    for dataset in datasets:
        lengths[dataset] = len(users_total[users_total["dataset"]==dataset])
        lengths_bot[dataset] = len(users_total[(users_total["dataset"]==dataset) & (users_total["label"]=='bot')])
        lengths_human[dataset] = len(users_total[(users_total["dataset"]==dataset) & (users_total["label"]=='human')])

    valid_combinations = list()
    for i in range(2,max_datasets_num):
        for comb in itertools.combinations(datasets,i):
            current_len = 0
            current_bot = 0
            current_human = 0


            for dataset in comb:
                current_len = current_len + lengths[dataset]
                current_bot = current_bot + lengths_bot[dataset]
                current_human = current_human + lengths_human[dataset]

            if (current_len > 0.1 * total_len and current_len < 0.5 * total_len) and (current_bot > 0.1 * total_len_bot and current_bot < 0.5 * total_len_bot) and (current_human > 0.1 * total_len_human and current_human < 0.5 * total_len_human):
                valid_combinations.append(comb)
    
    return valid_combinations

valid_combinations = get_valid_combinations(users_total,max_datasets_num=10)
print(f'Number of combinations: {len(valid_combinations)}')
# Out:
# Number of combinations: 1446068

# %%
import numpy as np
import pandas as pd
import itertools
import seaborn as sns
import matplotlib.pyplot as plt
from joypy import joyplot
sns.set_theme(style="whitegrid")

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.calibration import CalibratedClassifierCV

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score



def build_df(users_total,indomain_datasets):
    X = users_total[["dataset","label","statuses_count","followers_count","friends_count","favourites_count", \
            "listed_count","default_profile","geo_enabled","profile_use_background_image","verified","protected"]].fillna(0)

    X["label"] = X["label"].apply(lambda x: 0 if x == 'human' else 1)

    X[["statuses_count","followers_count","friends_count","favourites_count","listed_count"]] = X[["statuses_count","followers_count","friends_count","favourites_count","listed_count"]].apply(lambda x: np.log10(x+1))

    X.reset_index()

    #X_indomain = X[X["dataset"].isin(["fake_followers.csv","genuine_accounts.csv","social_spambots_1.csv","social_spambots_2.csv",
    #                                  "social_spambots_3.csv","traditional_spambots_1.csv","traditional_spambots_2.csv","traditional_spambots_3.csv"])].copy()
    X_indomain = X[X["dataset"].isin(indomain_datasets)].copy()
       
    
    X_train_indomain, X_test_indomain, y_train_indomain, y_test_indomain = train_test_split(X_indomain.drop(["dataset","label"], axis=1), X_indomain["label"], test_size=0.25, random_state=42)

    transformer = MinMaxScaler().fit(X_train_indomain)

    X_train_indomain = pd.DataFrame(transformer.transform(X_train_indomain),columns=["statuses_count","followers_count","friends_count","favourites_count", \
                "listed_count","default_profile","geo_enabled","profile_use_background_image","verified","protected"])
    X_test_indomain = pd.DataFrame(transformer.transform(X_test_indomain),columns=["statuses_count","followers_count","friends_count","favourites_count", \
                "listed_count","default_profile","geo_enabled","profile_use_background_image","verified","protected"])


    X_outdomain = X[~X["dataset"].isin(indomain_datasets)].copy()

    y_outdomain = X_outdomain[["dataset","label"]]
    X_outdomain = pd.DataFrame(transformer.transform(X_outdomain.drop(["dataset","label"], axis=1)),columns=["statuses_count","followers_count","friends_count","favourites_count", \
                "listed_count","default_profile","geo_enabled","profile_use_background_image","verified","protected"]).copy()

    
    return X_train_indomain, X_test_indomain, y_train_indomain, y_test_indomain,X_outdomain,y_outdomain

def build_df_grouped(users_total,indomain_datasets):
    X = users_total[["dataset_grouped","label","statuses_count","followers_count","friends_count","favourites_count", \
            "listed_count","default_profile","geo_enabled","profile_use_background_image","verified","protected"]].fillna(0)

    X["label"] = X["label"].apply(lambda x: 0 if x == 'human' else 1)

    X[["statuses_count","followers_count","friends_count","favourites_count","listed_count"]] = X[["statuses_count","followers_count","friends_count","favourites_count","listed_count"]].apply(lambda x: np.log10(x+1))

    X.reset_index()

    #X_indomain = X[X["dataset"].isin(["fake_followers.csv","genuine_accounts.csv","social_spambots_1.csv","social_spambots_2.csv",
    #                                  "social_spambots_3.csv","traditional_spambots_1.csv","traditional_spambots_2.csv","traditional_spambots_3.csv"])].copy()
    X_indomain = X[X["dataset_grouped"].isin(indomain_datasets)].copy()
       
    
    X_train_indomain, X_test_indomain, y_train_indomain, y_test_indomain = train_test_split(X_indomain.drop(["dataset_grouped","label"], axis=1), X_indomain["label"], test_size=0.25, random_state=42)

    transformer = MinMaxScaler().fit(X_train_indomain)

    X_train_indomain = pd.DataFrame(transformer.transform(X_train_indomain),columns=["statuses_count","followers_count","friends_count","favourites_count", \
                "listed_count","default_profile","geo_enabled","profile_use_background_image","verified","protected"])
    X_test_indomain = pd.DataFrame(transformer.transform(X_test_indomain),columns=["statuses_count","followers_count","friends_count","favourites_count", \
                "listed_count","default_profile","geo_enabled","profile_use_background_image","verified","protected"])


    X_outdomain = X[~X["dataset_grouped"].isin(indomain_datasets)].copy()

    y_outdomain = X_outdomain[["dataset_grouped","label"]]
    X_outdomain = pd.DataFrame(transformer.transform(X_outdomain.drop(["dataset_grouped","label"], axis=1)),columns=["statuses_count","followers_count","friends_count","favourites_count", \
                "listed_count","default_profile","geo_enabled","profile_use_background_image","verified","protected"]).copy()

    
    return X_train_indomain, X_test_indomain, y_train_indomain, y_test_indomain,X_outdomain,y_outdomain




def run_experiment(X_train_indomain,X_test_indomain,y_train_indomain,y_test_indomain,X_outdomain,y_outdomain,n_clusters,experiment_id):
    """
    This experiment tests if using clustering, and then scoring the data using  the classifier trained on only one cluster (i.e. consider only a subset of data for training)
    is a good idea.
    Counter-intuitive, but might work. 
    """

    df_results = pd.DataFrame(columns=['experiment_id', 'model', 'auc_indomain','auc_outdomain',"n_clusters","datasets_outdomain"])


    #Train baseline RandomForest using indomain data
    clf_ = RandomForestClassifier(random_state=42)
    clf = CalibratedClassifierCV(base_estimator=clf_)

    clf.fit(X_train_indomain,y_train_indomain)


    ## Baseline model: Get AUC for indomain and outdomain
    y_test_scored = clf.predict_proba(X_test_indomain)

    auc_baseline = roc_auc_score(y_test_indomain,y_test_scored[:,1])

    y_test_scored_out = clf.predict_proba(X_outdomain)

    auc_out_baseline = roc_auc_score(y_outdomain["label"],y_test_scored_out[:,1])

    df_results = df_results.append({'experiment_id': experiment_id,"model" : "baseline", "auc_indomain" : auc_baseline,"auc_outdomain" : auc_out_baseline,"n_clusters" : n_clusters,"datasets_outdomain" : ', '.join(y_outdomain.dataset.unique())}, ignore_index=True)
    
    ## Do clustering on the selected columns (using indomain data)

    df_to_cluster = X_train_indomain[["friends_count","followers_count"]]
    clusterer = KMeans(n_clusters=n_clusters, random_state=42)
    clusterer.fit(df_to_cluster)

    X_train_cluster = pd.DataFrame(clusterer.predict(X_train_indomain[["friends_count","followers_count"]]),columns=["cluster"])

    X_train_cluster_dict = dict()
    clf_ = dict()

    
    ## Then train a RandomForestClassifier for each cluster
    X_train_indomain_copy = X_train_indomain.copy()
    X_train_indomain_copy["index"] = X_train_indomain_copy.index

    for current_cluster in range(0,n_clusters):

        X_train_cluster_dict[current_cluster] = X_train_cluster[X_train_cluster["cluster"] == current_cluster].copy()
        
        X_train_cluster_dict[current_cluster]["index"] = X_train_cluster_dict[current_cluster].index

        X_train_cluster_dict[current_cluster] = pd.merge(X_train_indomain_copy, X_train_cluster_dict[current_cluster], on="index", how="inner")
        y_train_segment = np.take(y_train_indomain,X_train_cluster_dict[current_cluster]["index"],axis=0)

        clf_[current_cluster] = RandomForestClassifier(random_state=42)
        clf_[current_cluster].fit(X_train_cluster_dict[current_cluster].drop(columns=["index","cluster"]).copy(),y_train_segment)


    ## Now predict ALL indomain data using ALL the RandomForestClassifier trained by each cluster, and select the one with highest indomain AUC
    scores = dict()
    scores_out = dict()
    # best_cluster = 0
    # max_auc = 0
    for current_cluster in range(0,n_clusters):
        try:
            scores[current_cluster] = clf_[current_cluster].predict_proba(X_test_indomain)
            auc = roc_auc_score(y_test_indomain,scores[current_cluster][:,1])

            scores_out[current_cluster] = clf_[current_cluster].predict_proba(X_outdomain)
            auc_out = roc_auc_score(y_outdomain["label"],scores_out[current_cluster][:,1])

            df_results = df_results.append({'experiment_id': experiment_id,"model" : current_cluster, "auc_indomain" : auc,"auc_outdomain" : auc_out,"n_clusters" : n_clusters,"datasets_outdomain" : ', '.join(y_outdomain.dataset.unique())}, ignore_index=True)
        except:
            df_results = df_results.append({'experiment_id': experiment_id,"model" : current_cluster, "auc_indomain" : "bad_cluster","auc_outdomain" : "bad_cluster","n_clusters" : n_clusters,"datasets_outdomain" : ', '.join(y_outdomain.dataset.unique())}, ignore_index=True)
        #not doing anything with this for now
        # if auc > max_auc:
        #     max_auc = auc
        #     best_cluster = current_cluster
        
    
    return df_results




def run_experiment_2(X_train_indomain,X_test_indomain,y_train_indomain,y_test_indomain,X_outdomain,y_outdomain,n_clusters,experiment_id):
    """
    This experiment tests if using clustering, and then scoring the data using all the clusters (mixture of experts) is a good idea. 
    """

    df_results = pd.DataFrame(columns=['experiment_id', 'model', 'auc_indomain','auc_outdomain',"n_clusters","datasets_outdomain"])


    #Train baseline RandomForest using indomain data
    clf_ = RandomForestClassifier(random_state=42)
    clf = CalibratedClassifierCV(base_estimator=clf_)

    clf.fit(X_train_indomain,y_train_indomain)


    ## Baseline model: Get AUC for indomain and outdomain
    y_test_scored = clf.predict_proba(X_test_indomain)

    auc_baseline = roc_auc_score(y_test_indomain,y_test_scored[:,1])

    y_test_scored_out = clf.predict_proba(X_outdomain)

    auc_out_baseline = roc_auc_score(y_outdomain["label"],y_test_scored_out[:,1])

    df_results = df_results.append({'experiment_id': experiment_id,"model" : "baseline", "auc_indomain" : auc_baseline,"auc_outdomain" : auc_out_baseline,"n_clusters" : n_clusters,"datasets_outdomain" : ', '.join(y_outdomain.dataset.unique())}, ignore_index=True)
    
    ## Do clustering on the selected columns (using indomain data)

    df_to_cluster = X_train_indomain[["friends_count","followers_count"]]
    clusterer = KMeans(n_clusters=n_clusters, random_state=42)
    clusterer.fit(df_to_cluster)

    X_train_cluster = pd.DataFrame(clusterer.predict(X_train_indomain[["friends_count","followers_count"]]),columns=["cluster"])
    X_test_cluster = pd.DataFrame(clusterer.predict(X_test_indomain[["friends_count","followers_count"]]),columns=["cluster"])
    X_outdomain_cluster = pd.DataFrame(clusterer.predict(X_outdomain[["friends_count","followers_count"]]),columns=["cluster"])
    
    
    X_train_cluster_dict = dict()
    X_test_cluster_dict = dict()
    X_outdomain_cluster_dict = dict()
    y_test_segment = dict()
    y_outdomain_segment = dict()
    
    clf_ = dict()

    
    ## Then train a RandomForestClassifier for each cluster
    X_train_indomain_copy = X_train_indomain.copy()
    X_train_indomain_copy["index"] = X_train_indomain_copy.index
    X_test_indomain_copy = X_test_indomain.copy()
    X_test_indomain_copy["index"] = X_test_indomain_copy.index
    X_outdomain_copy = X_outdomain.copy()
    X_outdomain_copy["index"] = X_outdomain_copy.index
    
    for current_cluster in range(0,n_clusters):

        X_train_cluster_dict[current_cluster] = X_train_cluster[X_train_cluster["cluster"] == current_cluster].copy()
        X_train_cluster_dict[current_cluster]["index"] = X_train_cluster_dict[current_cluster].index
        X_train_cluster_dict[current_cluster] = pd.merge(X_train_indomain_copy, X_train_cluster_dict[current_cluster], on="index", how="inner")
        y_train_segment = np.take(y_train_indomain,X_train_cluster_dict[current_cluster]["index"],axis=0)

        X_test_cluster_dict[current_cluster] = X_test_cluster[X_test_cluster["cluster"] == current_cluster].copy()
        X_test_cluster_dict[current_cluster]["index"] = X_test_cluster_dict[current_cluster].index
        X_test_cluster_dict[current_cluster] = pd.merge(X_test_indomain_copy, X_test_cluster_dict[current_cluster], on="index", how="inner")
        y_test_segment[current_cluster] = np.take(y_test_indomain,X_test_cluster_dict[current_cluster]["index"],axis=0)
        
        X_outdomain_cluster_dict[current_cluster] = X_outdomain_cluster[X_outdomain_cluster["cluster"] == current_cluster].copy()
        X_outdomain_cluster_dict[current_cluster]["index"] = X_outdomain_cluster_dict[current_cluster].index
        X_outdomain_cluster_dict[current_cluster] = pd.merge(X_outdomain_copy, X_outdomain_cluster_dict[current_cluster], on="index", how="inner")
        y_outdomain_segment[current_cluster] = np.take(y_outdomain,X_outdomain_cluster_dict[current_cluster]["index"],axis=0)
        
                

        clf_[current_cluster] = RandomForestClassifier(random_state=42)
        clf_[current_cluster].fit(X_train_cluster_dict[current_cluster].drop(columns=["index","cluster"]).copy(),y_train_segment)


    ## Now predict ALL indomain data using ALL the RandomForestClassifier trained by each cluster, and select the one with highest indomain AUC
    scores = dict()
    scores_out = dict()
    # best_cluster = 0
    # max_auc = 0
    scores_full_list = list()
    scores_out_full_list = list()
    y_test_full_list = list()
    y_outdomain_full_list = list()
    for current_cluster in range(0,n_clusters):
#         scores[current_cluster] = clf_[current_cluster].predict_proba(X_test_indomain)
#         auc = roc_auc_score(y_test_indomain,scores[current_cluster][:,1])

#         scores_out[current_cluster] = clf_[current_cluster].predict_proba(X_outdomain)
#         auc_out = roc_auc_score(y_outdomain["label"],scores_out[current_cluster][:,1])

        print(f"X_test_cluster_dict[current_cluster] -------> {X_test_cluster_dict[current_cluster].columns}")
        print("")
        print(f"X_outdomain_cluster_dict[current_cluster] -------> {X_outdomain_cluster_dict[current_cluster].columns}")
    
        scores[current_cluster] = clf_[current_cluster].predict_proba(X_test_cluster_dict[current_cluster].drop(columns=["index","cluster"]))
        print(f"y_test_segment[current_cluster] -------> {y_test_segment[current_cluster]}")
        print(f"scores[current_cluster] -------> {scores[current_cluster]}")
    
        auc = roc_auc_score(y_test_segment[current_cluster],scores[current_cluster][:,1])
        
        scores_out[current_cluster] = clf_[current_cluster].predict_proba(X_outdomain_cluster_dict[current_cluster].drop(columns=["index","cluster"]))
        print(f"y_outdomain_segment[current_cluster] -------> {y_outdomain_segment[current_cluster]}")
        print(f"scores_out[current_cluster] -------> {scores_out[current_cluster]}")
        auc_out = roc_auc_score(y_outdomain_segment[current_cluster]["label"],scores_out[current_cluster][:,1])

        scores_full_list.append(np.asarray(scores[current_cluster][:,1]))
        scores_out_full_list.append(np.asarray(scores_out[current_cluster][:,1]))
        y_test_full_list.append(np.asarray(y_test_segment[current_cluster]))
        y_outdomain_full_list.append(np.asarray(y_outdomain_segment[current_cluster]["label"]))
        
        df_results = df_results.append({'experiment_id': experiment_id,"model" : current_cluster, "auc_indomain" : auc,"auc_outdomain" : auc_out,"n_clusters" : n_clusters,"datasets_outdomain" : ', '.join(y_outdomain.dataset.unique())}, ignore_index=True)

        #not doing anything with this for now
        # if auc > max_auc:
        #     max_auc = auc
        #     best_cluster = current_cluster
        
        

    print(f"np.concatenate(y_test_full_list, axis=None) -------> {np.concatenate(y_test_full_list, axis=None)}")
    
    auc = roc_auc_score(np.concatenate(y_test_full_list, axis=None),np.concatenate(scores_full_list, axis=None))
    auc_out = roc_auc_score(np.concatenate(y_outdomain_full_list, axis=None),np.concatenate(scores_out_full_list, axis=None))

    #return y_test_full_list
    df_results = df_results.append({'experiment_id': experiment_id,"model" : "aggregate", "auc_indomain" : auc,"auc_outdomain" : auc_out,"n_clusters" : n_clusters,"datasets_outdomain" : ', '.join(y_outdomain.dataset.unique())}, ignore_index=True)
         
    return df_results


def run_experiment_2_grouped(X_train_indomain,X_test_indomain,y_train_indomain,y_test_indomain,X_outdomain,y_outdomain,n_clusters,experiment_id):


    df_results = pd.DataFrame(columns=['experiment_id', 'model', 'auc_indomain','auc_outdomain',"n_clusters","datasets_outdomain"])


    #Train baseline RandomForest using indomain data
    clf_ = RandomForestClassifier(random_state=42)
    clf = CalibratedClassifierCV(base_estimator=clf_)

    clf.fit(X_train_indomain,y_train_indomain)


    ## Baseline model: Get AUC for indomain and outdomain
    y_test_scored = clf.predict_proba(X_test_indomain)

    auc_baseline = roc_auc_score(y_test_indomain,y_test_scored[:,1])

    y_test_scored_out = clf.predict_proba(X_outdomain)

    auc_out_baseline = roc_auc_score(y_outdomain["label"],y_test_scored_out[:,1])

    df_results = df_results.append({'experiment_id': experiment_id,"model" : "baseline", "auc_indomain" : auc_baseline,"auc_outdomain" : auc_out_baseline,"n_clusters" : n_clusters,"datasets_outdomain" : ', '.join(y_outdomain.dataset_grouped.unique())}, ignore_index=True)
    
    ## Do clustering on the selected columns (using indomain data)

    df_to_cluster = X_train_indomain[["friends_count","followers_count"]]
    clusterer = KMeans(n_clusters=n_clusters, random_state=42)
    clusterer.fit(df_to_cluster)

    X_train_cluster = pd.DataFrame(clusterer.predict(X_train_indomain[["friends_count","followers_count"]]),columns=["cluster"])
    X_test_cluster = pd.DataFrame(clusterer.predict(X_test_indomain[["friends_count","followers_count"]]),columns=["cluster"])
    X_outdomain_cluster = pd.DataFrame(clusterer.predict(X_outdomain[["friends_count","followers_count"]]),columns=["cluster"])
    
    
    X_train_cluster_dict = dict()
    X_test_cluster_dict = dict()
    X_outdomain_cluster_dict = dict()
    y_test_segment = dict()
    y_outdomain_segment = dict()
    
    clf_ = dict()

    
    ## Then train a RandomForestClassifier for each cluster
    X_train_indomain_copy = X_train_indomain.copy()
    X_train_indomain_copy["index"] = X_train_indomain_copy.index
    X_test_indomain_copy = X_test_indomain.copy()
    X_test_indomain_copy["index"] = X_test_indomain_copy.index
    X_outdomain_copy = X_outdomain.copy()
    X_outdomain_copy["index"] = X_outdomain_copy.index
    
    for current_cluster in range(0,n_clusters):

        X_train_cluster_dict[current_cluster] = X_train_cluster[X_train_cluster["cluster"] == current_cluster].copy()
        X_train_cluster_dict[current_cluster]["index"] = X_train_cluster_dict[current_cluster].index
        X_train_cluster_dict[current_cluster] = pd.merge(X_train_indomain_copy, X_train_cluster_dict[current_cluster], on="index", how="inner")
        y_train_segment = np.take(y_train_indomain,X_train_cluster_dict[current_cluster]["index"],axis=0)

        X_test_cluster_dict[current_cluster] = X_test_cluster[X_test_cluster["cluster"] == current_cluster].copy()
        X_test_cluster_dict[current_cluster]["index"] = X_test_cluster_dict[current_cluster].index
        X_test_cluster_dict[current_cluster] = pd.merge(X_test_indomain_copy, X_test_cluster_dict[current_cluster], on="index", how="inner")
        y_test_segment[current_cluster] = np.take(y_test_indomain,X_test_cluster_dict[current_cluster]["index"],axis=0)
        
        X_outdomain_cluster_dict[current_cluster] = X_outdomain_cluster[X_outdomain_cluster["cluster"] == current_cluster].copy()
        X_outdomain_cluster_dict[current_cluster]["index"] = X_outdomain_cluster_dict[current_cluster].index
        X_outdomain_cluster_dict[current_cluster] = pd.merge(X_outdomain_copy, X_outdomain_cluster_dict[current_cluster], on="index", how="inner")
        y_outdomain_segment[current_cluster] = np.take(y_outdomain,X_outdomain_cluster_dict[current_cluster]["index"],axis=0)
        
                

        clf_[current_cluster] = RandomForestClassifier(random_state=42)
        clf_[current_cluster].fit(X_train_cluster_dict[current_cluster].drop(columns=["index","cluster"]).copy(),y_train_segment)


    ## Now predict ALL indomain data using ALL the RandomForestClassifier trained by each cluster, and select the one with highest indomain AUC
    scores = dict()
    scores_out = dict()
    # best_cluster = 0
    # max_auc = 0
    scores_full_list = list()
    scores_out_full_list = list()
    y_test_full_list = list()
    y_outdomain_full_list = list()
    for current_cluster in range(0,n_clusters):
#         scores[current_cluster] = clf_[current_cluster].predict_proba(X_test_indomain)
#         auc = roc_auc_score(y_test_indomain,scores[current_cluster][:,1])

#         scores_out[current_cluster] = clf_[current_cluster].predict_proba(X_outdomain)
#         auc_out = roc_auc_score(y_outdomain["label"],scores_out[current_cluster][:,1])

     #   print(f"X_test_cluster_dict[current_cluster] -------> {X_test_cluster_dict[current_cluster].columns}")
     #   print("")
     #   print(f"X_outdomain_cluster_dict[current_cluster] -------> {X_outdomain_cluster_dict[current_cluster].columns}")
    
        scores[current_cluster] = clf_[current_cluster].predict_proba(X_test_cluster_dict[current_cluster].drop(columns=["index","cluster"]))
     #   print(f"y_test_segment[current_cluster] -------> {y_test_segment[current_cluster]}")
     #   print(f"scores[current_cluster] -------> {scores[current_cluster]}")
    
        auc = roc_auc_score(y_test_segment[current_cluster],scores[current_cluster][:,1])
        
        scores_out[current_cluster] = clf_[current_cluster].predict_proba(X_outdomain_cluster_dict[current_cluster].drop(columns=["index","cluster"]))
     #   print(f"y_outdomain_segment[current_cluster] -------> {y_outdomain_segment[current_cluster]}")
     #   print(f"scores_out[current_cluster] -------> {scores_out[current_cluster]}")
        auc_out = roc_auc_score(y_outdomain_segment[current_cluster]["label"],scores_out[current_cluster][:,1])

        scores_full_list.append(np.asarray(scores[current_cluster][:,1]))
        scores_out_full_list.append(np.asarray(scores_out[current_cluster][:,1]))
        y_test_full_list.append(np.asarray(y_test_segment[current_cluster]))
        y_outdomain_full_list.append(np.asarray(y_outdomain_segment[current_cluster]["label"]))
        
        df_results = df_results.append({'experiment_id': experiment_id,"model" : current_cluster, "auc_indomain" : auc,"auc_outdomain" : auc_out,"n_clusters" : n_clusters,"datasets_outdomain" : ', '.join(y_outdomain.dataset_grouped.unique())}, ignore_index=True)

        #not doing anything with this for now
        # if auc > max_auc:
        #     max_auc = auc
        #     best_cluster = current_cluster
        
        

    #print(f"np.concatenate(y_test_full_list, axis=None) -------> {np.concatenate(y_test_full_list, axis=None)}")
    
    auc = roc_auc_score(np.concatenate(y_test_full_list, axis=None),np.concatenate(scores_full_list, axis=None))
    auc_out = roc_auc_score(np.concatenate(y_outdomain_full_list, axis=None),np.concatenate(scores_out_full_list, axis=None))

    #return y_test_full_list
    df_results = df_results.append({'experiment_id': experiment_id,"model" : "aggregate", "auc_indomain" : auc,"auc_outdomain" : auc_out,"n_clusters" : n_clusters,"datasets_outdomain" : ', '.join(y_outdomain.dataset_grouped.unique())}, ignore_index=True)
         
    return df_results


def get_valid_combinations(users_total,max_datasets_num=8):

    datasets = users_total["dataset"].unique()

    total_len = len(users_total)
    total_len_bot = len(users_total[users_total["label"]=='bot'])
    total_len_human = len(users_total[users_total["label"]=='human'])

    lengths = dict()
    lengths_bot = dict()
    lengths_human = dict()
    for dataset in datasets:
        lengths[dataset] = len(users_total[users_total["dataset"]==dataset])
        lengths_bot[dataset] = len(users_total[(users_total["dataset"]==dataset) & (users_total["label"]=='bot')])
        lengths_human[dataset] = len(users_total[(users_total["dataset"]==dataset) & (users_total["label"]=='human')])

    valid_combinations = list()
    for i in range(2,max_datasets_num):
        for comb in itertools.combinations(datasets,i):
            current_len = 0
            current_bot = 0
            current_human = 0


            for dataset in comb:
                current_len = current_len + lengths[dataset]
                current_bot = current_bot + lengths_bot[dataset]
                current_human = current_human + lengths_human[dataset]

            if (current_len > 0.5 * total_len and current_len < 0.8 * total_len) and (current_bot > 0.5 * total_len_bot and current_bot < 0.8 * total_len_bot) and (current_human > 0.5 * total_len_human and current_human < 0.8 * total_len_human):
                valid_combinations.append(comb)
    
    return valid_combinations

def get_valid_combinations_10_percent(users_total,max_datasets_num=8):

    datasets = users_total["dataset"].unique()

    total_len = len(users_total)
    total_len_bot = len(users_total[users_total["label"]=='bot'])
    total_len_human = len(users_total[users_total["label"]=='human'])

    lengths = dict()
    lengths_bot = dict()
    lengths_human = dict()
    for dataset in datasets:
        lengths[dataset] = len(users_total[users_total["dataset"]==dataset])
        lengths_bot[dataset] = len(users_total[(users_total["dataset"]==dataset) & (users_total["label"]=='bot')])
        lengths_human[dataset] = len(users_total[(users_total["dataset"]==dataset) & (users_total["label"]=='human')])

    valid_combinations = list()
    for i in range(2,max_datasets_num):
        for comb in itertools.combinations(datasets,i):
            current_len = 0
            current_bot = 0
            current_human = 0


            for dataset in comb:
                current_len = current_len + lengths[dataset]
                current_bot = current_bot + lengths_bot[dataset]
                current_human = current_human + lengths_human[dataset]

            if (current_len > 0.1 * total_len and current_len < 0.5 * total_len) and (current_bot > 0.1 * total_len_bot and current_bot < 0.5 * total_len_bot) and (current_human > 0.1 * total_len_human and current_human < 0.5 * total_len_human):
                valid_combinations.append(comb)
    
    return valid_combinations

def get_valid_combinations_1_percent(users_total,max_datasets_num=8):

    datasets = users_total["dataset"].unique()

    total_len = len(users_total)
    total_len_bot = len(users_total[users_total["label"]=='bot'])
    total_len_human = len(users_total[users_total["label"]=='human'])

    lengths = dict()
    lengths_bot = dict()
    lengths_human = dict()
    for dataset in datasets:
        lengths[dataset] = len(users_total[users_total["dataset"]==dataset])
        lengths_bot[dataset] = len(users_total[(users_total["dataset"]==dataset) & (users_total["label"]=='bot')])
        lengths_human[dataset] = len(users_total[(users_total["dataset"]==dataset) & (users_total["label"]=='human')])

    valid_combinations = list()
    for i in range(2,max_datasets_num):
        for comb in itertools.combinations(datasets,i):
            current_len = 0
            current_bot = 0
            current_human = 0


            for dataset in comb:
                current_len = current_len + lengths[dataset]
                current_bot = current_bot + lengths_bot[dataset]
                current_human = current_human + lengths_human[dataset]

            if (current_len > 0.01 * total_len and current_len < 0.1 * total_len) and (current_bot > 0.01 * total_len_bot and current_bot < 0.1 * total_len_bot) and (current_human > 0.01 * total_len_human and current_human < 0.1 * total_len_human):
                valid_combinations.append(comb)
    
    return valid_combinations

def get_valid_combinations_grouped(users_total,max_datasets_num=8):

    datasets = users_total["dataset_grouped"].unique()

    total_len = len(users_total)
    total_len_bot = len(users_total[users_total["label"]=='bot'])
    total_len_human = len(users_total[users_total["label"]=='human'])

    lengths = dict()
    lengths_bot = dict()
    lengths_human = dict()
    for dataset in datasets:
        lengths[dataset] = len(users_total[users_total["dataset_grouped"]==dataset])
        lengths_bot[dataset] = len(users_total[(users_total["dataset_grouped"]==dataset) & (users_total["label"]=='bot')])
        lengths_human[dataset] = len(users_total[(users_total["dataset_grouped"]==dataset) & (users_total["label"]=='human')])

    valid_combinations = list()
    for i in range(2,max_datasets_num):
        for comb in itertools.combinations(datasets,i):
            current_len = 0
            current_bot = 0
            current_human = 0


            for dataset in comb:
                current_len = current_len + lengths[dataset]
                current_bot = current_bot + lengths_bot[dataset]
                current_human = current_human + lengths_human[dataset]

            if (current_len > 0.5 * total_len and current_len < 0.8 * total_len) and (current_bot > 0.5 * total_len_bot and current_bot < 0.8 * total_len_bot) and (current_human > 0.5 * total_len_human and current_human < 0.8 * total_len_human):
                valid_combinations.append(comb)
    
    return valid_combinations




users = pd.read_csv("users2.csv")
users_cresci = pd.read_csv("users_cresci.csv")
users_total = users.append(users_cresci, ignore_index=True)

users_total["dataset_grouped"] = users_total["dataset"].apply(lambda x: 'cresci_2017' if x in ['fake_followers.csv', 'genuine_accounts.csv',
       'social_spambots_1.csv', 'social_spambots_2.csv',
       'social_spambots_3.csv', 'traditional_spambots_1.csv',
       'traditional_spambots_2.csv', 'traditional_spambots_3.csv',
       'traditional_spambots_4.csv'] else ('cresci_2015' if x in ['E13_users.csv', 'FSF_users.csv',
       'INT_users.csv', 'TFP_users.csv', 'TWT_users.csv'] else x))


# 122659 valid combinations
#valid_combinations = get_valid_combinations(users_total,max_datasets_num=10)

# 619 valid combinations
#valid_combinations = get_valid_combinations_grouped(users_total,max_datasets_num=10)

valid_combinations = get_valid_combinations_1_percent(users_total,max_datasets_num=10)

print(f'Number of combinations: {len(valid_combinations)}')

current_exp = 0
for indomain in valid_combinations:
    print(f'indomain datasets: {indomain}')
    print(" ")
    df_results = pd.DataFrame(columns=['experiment_id', 'model', 'auc_indomain','auc_outdomain',"n_clusters","datasets_outdomain"])

    X_train, X_test, y_train, y_test,X_outdomain,y_outdomain = build_df(users_total,indomain)
    df_results = df_results.append(run_experiment(X_train, X_test, y_train, y_test,X_outdomain,y_outdomain,2,current_exp),ignore_index=True)
    current_exp = current_exp + 1
    df_results = df_results.append(run_experiment(X_train, X_test, y_train, y_test,X_outdomain,y_outdomain,3,current_exp),ignore_index=True)
    df_results.to_csv("df_results.csv",mode="a",index=False,header=False)
    current_exp = current_exp + 1
# Out:
# Number of combinations: 3794
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv')
#
# indomain datasets: ('botwiki-2019.tsv', 'cresci-rtbust-2019.tsv')
#
# indomain datasets: ('botwiki-2019.tsv', 'gilani-2017.tsv')
#
# indomain datasets: ('botwiki-2019.tsv', 'varol-2017.new3')
#
# indomain datasets: ('botwiki-2019.tsv', 'E13_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'gilani-2017.tsv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'pronbots.tsv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'varol-2017.new3')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_1.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_3.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_1.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'FSF_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'INT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'TWT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'gilani-2017.tsv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'pronbots.tsv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'varol-2017.new3')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_1.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_3.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_1.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'E13_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'FSF_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'INT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'TWT_users.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'vendor-purchased-2019.tsv')
#
# indomain datasets: ('gilani-2017.tsv', 'social_spambots_1.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'social_spambots_3.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'traditional_spambots_1.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'FSF_users.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'INT_users.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'TFP_users.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'TWT_users.csv')
#
# indomain datasets: ('pronbots.tsv', 'varol-2017.new3')
#
# indomain datasets: ('pronbots.tsv', 'E13_users.csv')
#
# indomain datasets: ('pronbots.tsv', 'TFP_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'varol-2017.new3')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'E13_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'TFP_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'social_spambots_1.csv')
#
# indomain datasets: ('varol-2017.new3', 'social_spambots_3.csv')
#
# indomain datasets: ('varol-2017.new3', 'traditional_spambots_1.csv')
#
# indomain datasets: ('varol-2017.new3', 'traditional_spambots_2.csv')
#
# indomain datasets: ('varol-2017.new3', 'traditional_spambots_3.csv')
#
# indomain datasets: ('varol-2017.new3', 'traditional_spambots_4.csv')
#
# indomain datasets: ('varol-2017.new3', 'FSF_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'INT_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'TFP_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'TWT_users.csv')
#
# indomain datasets: ('social_spambots_1.csv', 'E13_users.csv')
#
# indomain datasets: ('social_spambots_1.csv', 'TFP_users.csv')
#
# indomain datasets: ('social_spambots_3.csv', 'E13_users.csv')
#
# indomain datasets: ('social_spambots_3.csv', 'TFP_users.csv')
#
# indomain datasets: ('traditional_spambots_1.csv', 'E13_users.csv')
#
# indomain datasets: ('traditional_spambots_1.csv', 'TFP_users.csv')
#
# indomain datasets: ('traditional_spambots_3.csv', 'E13_users.csv')
#
# indomain datasets: ('traditional_spambots_3.csv', 'TFP_users.csv')
#
# indomain datasets: ('traditional_spambots_4.csv', 'E13_users.csv')
#
# indomain datasets: ('traditional_spambots_4.csv', 'TFP_users.csv')
#
# indomain datasets: ('E13_users.csv', 'FSF_users.csv')
#
# indomain datasets: ('E13_users.csv', 'INT_users.csv')
#
# indomain datasets: ('E13_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('FSF_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('INT_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'gilani-2017.tsv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'pronbots.tsv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'varol-2017.new3')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'social_spambots_1.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'social_spambots_3.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'traditional_spambots_1.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'E13_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'FSF_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'INT_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'TFP_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'TWT_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'cresci-rtbust-2019.tsv', 'gilani-2017.tsv')
#
# indomain datasets: ('botwiki-2019.tsv', 'cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv')
#
# indomain datasets: ('botwiki-2019.tsv', 'cresci-rtbust-2019.tsv', 'varol-2017.new3')
#
# indomain datasets: ('botwiki-2019.tsv', 'cresci-rtbust-2019.tsv', 'social_spambots_1.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'cresci-rtbust-2019.tsv', 'social_spambots_3.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'cresci-rtbust-2019.tsv', 'traditional_spambots_1.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'cresci-rtbust-2019.tsv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'cresci-rtbust-2019.tsv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'cresci-rtbust-2019.tsv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'cresci-rtbust-2019.tsv', 'E13_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'cresci-rtbust-2019.tsv', 'FSF_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'cresci-rtbust-2019.tsv', 'INT_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'cresci-rtbust-2019.tsv', 'TFP_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'cresci-rtbust-2019.tsv', 'TWT_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'gilani-2017.tsv', 'vendor-purchased-2019.tsv')
#
# indomain datasets: ('botwiki-2019.tsv', 'gilani-2017.tsv', 'social_spambots_3.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'gilani-2017.tsv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'gilani-2017.tsv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'gilani-2017.tsv', 'TFP_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'gilani-2017.tsv', 'TWT_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'pronbots.tsv', 'E13_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'pronbots.tsv', 'TFP_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'vendor-purchased-2019.tsv', 'varol-2017.new3')
#
# indomain datasets: ('botwiki-2019.tsv', 'vendor-purchased-2019.tsv', 'E13_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'vendor-purchased-2019.tsv', 'TFP_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'varol-2017.new3', 'social_spambots_1.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'varol-2017.new3', 'social_spambots_3.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'varol-2017.new3', 'traditional_spambots_1.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'varol-2017.new3', 'traditional_spambots_2.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'varol-2017.new3', 'traditional_spambots_3.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'varol-2017.new3', 'traditional_spambots_4.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'varol-2017.new3', 'FSF_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'varol-2017.new3', 'TFP_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'varol-2017.new3', 'TWT_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'social_spambots_1.csv', 'E13_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'social_spambots_1.csv', 'TFP_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'social_spambots_3.csv', 'E13_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'social_spambots_3.csv', 'TFP_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'traditional_spambots_1.csv', 'E13_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'traditional_spambots_1.csv', 'TFP_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'traditional_spambots_2.csv', 'E13_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'traditional_spambots_2.csv', 'TFP_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'traditional_spambots_3.csv', 'E13_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'traditional_spambots_3.csv', 'TFP_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'traditional_spambots_4.csv', 'E13_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'traditional_spambots_4.csv', 'TFP_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'E13_users.csv', 'FSF_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'E13_users.csv', 'INT_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'E13_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'FSF_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'INT_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'gilani-2017.tsv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'pronbots.tsv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'varol-2017.new3')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'social_spambots_1.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'social_spambots_3.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'traditional_spambots_1.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'E13_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'FSF_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'INT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'gilani-2017.tsv', 'vendor-purchased-2019.tsv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'gilani-2017.tsv', 'social_spambots_1.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'gilani-2017.tsv', 'social_spambots_3.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'gilani-2017.tsv', 'traditional_spambots_1.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'gilani-2017.tsv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'gilani-2017.tsv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'gilani-2017.tsv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'gilani-2017.tsv', 'FSF_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'gilani-2017.tsv', 'INT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'gilani-2017.tsv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'gilani-2017.tsv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'pronbots.tsv', 'social_spambots_3.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'pronbots.tsv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'pronbots.tsv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'pronbots.tsv', 'E13_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'pronbots.tsv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'varol-2017.new3')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_1.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_3.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'traditional_spambots_1.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'E13_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'FSF_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'INT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'varol-2017.new3', 'social_spambots_1.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'varol-2017.new3', 'social_spambots_3.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'varol-2017.new3', 'traditional_spambots_1.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'varol-2017.new3', 'traditional_spambots_2.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'varol-2017.new3', 'traditional_spambots_3.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'varol-2017.new3', 'traditional_spambots_4.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'varol-2017.new3', 'FSF_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'varol-2017.new3', 'INT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'varol-2017.new3', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'varol-2017.new3', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_1.csv', 'social_spambots_3.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_1.csv', 'traditional_spambots_1.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_1.csv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_1.csv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_1.csv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_1.csv', 'E13_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_1.csv', 'FSF_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_1.csv', 'INT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_1.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_1.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_1.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_3.csv', 'E13_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_3.csv', 'FSF_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_3.csv', 'INT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_3.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_3.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_1.csv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_1.csv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_1.csv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_1.csv', 'E13_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_1.csv', 'FSF_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_1.csv', 'INT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_1.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_1.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_2.csv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_2.csv', 'FSF_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_2.csv', 'INT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_2.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_3.csv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_3.csv', 'E13_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_3.csv', 'FSF_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_3.csv', 'INT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_3.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_3.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_4.csv', 'E13_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_4.csv', 'FSF_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_4.csv', 'INT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_4.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_4.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'E13_users.csv', 'FSF_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'E13_users.csv', 'INT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'E13_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'FSF_users.csv', 'INT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'FSF_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'FSF_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'INT_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'INT_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'gilani-2017.tsv', 'vendor-purchased-2019.tsv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'gilani-2017.tsv', 'social_spambots_1.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'gilani-2017.tsv', 'social_spambots_3.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'gilani-2017.tsv', 'traditional_spambots_1.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'gilani-2017.tsv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'gilani-2017.tsv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'gilani-2017.tsv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'gilani-2017.tsv', 'FSF_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'gilani-2017.tsv', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'gilani-2017.tsv', 'TWT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'pronbots.tsv', 'social_spambots_3.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'pronbots.tsv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'pronbots.tsv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'pronbots.tsv', 'E13_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'pronbots.tsv', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'varol-2017.new3')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_1.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_3.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'traditional_spambots_1.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'E13_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'FSF_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'INT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'TWT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'varol-2017.new3', 'social_spambots_1.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'varol-2017.new3', 'social_spambots_3.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'varol-2017.new3', 'traditional_spambots_1.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'varol-2017.new3', 'traditional_spambots_2.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'varol-2017.new3', 'traditional_spambots_3.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'varol-2017.new3', 'traditional_spambots_4.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'varol-2017.new3', 'FSF_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'varol-2017.new3', 'INT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'varol-2017.new3', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'varol-2017.new3', 'TWT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_1.csv', 'social_spambots_3.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_1.csv', 'traditional_spambots_1.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_1.csv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_1.csv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_1.csv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_1.csv', 'E13_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_1.csv', 'FSF_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_1.csv', 'INT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_1.csv', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_1.csv', 'TWT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_1.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_3.csv', 'E13_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_3.csv', 'FSF_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_3.csv', 'INT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_3.csv', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_3.csv', 'TWT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_1.csv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_1.csv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_1.csv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_1.csv', 'E13_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_1.csv', 'FSF_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_1.csv', 'INT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_1.csv', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_1.csv', 'TWT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_2.csv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_2.csv', 'E13_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_2.csv', 'FSF_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_2.csv', 'INT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_2.csv', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_2.csv', 'TWT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_3.csv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_3.csv', 'E13_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_3.csv', 'FSF_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_3.csv', 'INT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_3.csv', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_3.csv', 'TWT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_4.csv', 'E13_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_4.csv', 'FSF_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_4.csv', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_4.csv', 'TWT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'E13_users.csv', 'FSF_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'E13_users.csv', 'INT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'E13_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'FSF_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'FSF_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'INT_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'INT_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_3.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'vendor-purchased-2019.tsv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'vendor-purchased-2019.tsv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'vendor-purchased-2019.tsv', 'TFP_users.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'vendor-purchased-2019.tsv', 'TWT_users.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'social_spambots_1.csv', 'social_spambots_3.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'social_spambots_1.csv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'social_spambots_1.csv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'social_spambots_1.csv', 'TFP_users.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'social_spambots_3.csv', 'traditional_spambots_1.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'social_spambots_3.csv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'social_spambots_3.csv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'social_spambots_3.csv', 'TFP_users.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'social_spambots_3.csv', 'TWT_users.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'traditional_spambots_1.csv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'traditional_spambots_1.csv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'traditional_spambots_1.csv', 'TFP_users.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'traditional_spambots_2.csv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'traditional_spambots_2.csv', 'FSF_users.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'traditional_spambots_2.csv', 'INT_users.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'traditional_spambots_2.csv', 'TFP_users.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'traditional_spambots_2.csv', 'TWT_users.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'traditional_spambots_3.csv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'traditional_spambots_3.csv', 'FSF_users.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'traditional_spambots_3.csv', 'TFP_users.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'traditional_spambots_3.csv', 'TWT_users.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'traditional_spambots_4.csv', 'TFP_users.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'FSF_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'INT_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('gilani-2017.tsv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('pronbots.tsv', 'vendor-purchased-2019.tsv', 'E13_users.csv')
#
# indomain datasets: ('pronbots.tsv', 'vendor-purchased-2019.tsv', 'TFP_users.csv')
#
# indomain datasets: ('pronbots.tsv', 'varol-2017.new3', 'traditional_spambots_2.csv')
#
# indomain datasets: ('pronbots.tsv', 'varol-2017.new3', 'TFP_users.csv')
#
# indomain datasets: ('pronbots.tsv', 'social_spambots_3.csv', 'E13_users.csv')
#
# indomain datasets: ('pronbots.tsv', 'social_spambots_3.csv', 'TFP_users.csv')
#
# indomain datasets: ('pronbots.tsv', 'traditional_spambots_2.csv', 'E13_users.csv')
#
# indomain datasets: ('pronbots.tsv', 'traditional_spambots_2.csv', 'TFP_users.csv')
#
# indomain datasets: ('pronbots.tsv', 'traditional_spambots_3.csv', 'E13_users.csv')
#
# indomain datasets: ('pronbots.tsv', 'traditional_spambots_3.csv', 'TFP_users.csv')
#
# indomain datasets: ('pronbots.tsv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'varol-2017.new3', 'social_spambots_1.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'varol-2017.new3', 'social_spambots_3.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'varol-2017.new3', 'traditional_spambots_1.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'varol-2017.new3', 'traditional_spambots_2.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'varol-2017.new3', 'traditional_spambots_3.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'varol-2017.new3', 'traditional_spambots_4.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'varol-2017.new3', 'FSF_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'varol-2017.new3', 'TFP_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'varol-2017.new3', 'TWT_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'social_spambots_1.csv', 'E13_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'social_spambots_1.csv', 'TFP_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'social_spambots_3.csv', 'E13_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'social_spambots_3.csv', 'TFP_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'traditional_spambots_1.csv', 'E13_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'traditional_spambots_1.csv', 'TFP_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'traditional_spambots_2.csv', 'E13_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'traditional_spambots_2.csv', 'TFP_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'traditional_spambots_3.csv', 'E13_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'traditional_spambots_3.csv', 'TFP_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'traditional_spambots_4.csv', 'E13_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'traditional_spambots_4.csv', 'TFP_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'E13_users.csv', 'FSF_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'E13_users.csv', 'INT_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'E13_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'FSF_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'INT_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'social_spambots_1.csv', 'social_spambots_3.csv')
#
# indomain datasets: ('varol-2017.new3', 'social_spambots_1.csv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('varol-2017.new3', 'social_spambots_1.csv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('varol-2017.new3', 'social_spambots_1.csv', 'TFP_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'social_spambots_1.csv', 'TWT_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'social_spambots_3.csv', 'traditional_spambots_1.csv')
#
# indomain datasets: ('varol-2017.new3', 'social_spambots_3.csv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('varol-2017.new3', 'social_spambots_3.csv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('varol-2017.new3', 'social_spambots_3.csv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('varol-2017.new3', 'social_spambots_3.csv', 'FSF_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'social_spambots_3.csv', 'INT_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'social_spambots_3.csv', 'TFP_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'social_spambots_3.csv', 'TWT_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'traditional_spambots_1.csv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('varol-2017.new3', 'traditional_spambots_1.csv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('varol-2017.new3', 'traditional_spambots_1.csv', 'TFP_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'traditional_spambots_1.csv', 'TWT_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('varol-2017.new3', 'traditional_spambots_2.csv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('varol-2017.new3', 'traditional_spambots_2.csv', 'FSF_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'traditional_spambots_2.csv', 'INT_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'traditional_spambots_2.csv', 'TFP_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'traditional_spambots_2.csv', 'TWT_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'traditional_spambots_3.csv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('varol-2017.new3', 'traditional_spambots_3.csv', 'FSF_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'traditional_spambots_3.csv', 'INT_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'traditional_spambots_3.csv', 'TFP_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'traditional_spambots_3.csv', 'TWT_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'traditional_spambots_4.csv', 'TFP_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'traditional_spambots_4.csv', 'TWT_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'FSF_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'INT_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('varol-2017.new3', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('social_spambots_1.csv', 'social_spambots_3.csv', 'E13_users.csv')
#
# indomain datasets: ('social_spambots_1.csv', 'social_spambots_3.csv', 'TFP_users.csv')
#
# indomain datasets: ('social_spambots_1.csv', 'traditional_spambots_1.csv', 'E13_users.csv')
#
# indomain datasets: ('social_spambots_1.csv', 'traditional_spambots_1.csv', 'TFP_users.csv')
#
# indomain datasets: ('social_spambots_1.csv', 'traditional_spambots_2.csv', 'E13_users.csv')
#
# indomain datasets: ('social_spambots_1.csv', 'traditional_spambots_2.csv', 'TFP_users.csv')
#
# indomain datasets: ('social_spambots_1.csv', 'traditional_spambots_3.csv', 'E13_users.csv')
#
# indomain datasets: ('social_spambots_1.csv', 'traditional_spambots_3.csv', 'TFP_users.csv')
#
# indomain datasets: ('social_spambots_1.csv', 'traditional_spambots_4.csv', 'E13_users.csv')
#
# indomain datasets: ('social_spambots_1.csv', 'traditional_spambots_4.csv', 'TFP_users.csv')
#
# indomain datasets: ('social_spambots_1.csv', 'E13_users.csv', 'FSF_users.csv')
#
# indomain datasets: ('social_spambots_1.csv', 'E13_users.csv', 'INT_users.csv')
#
# indomain datasets: ('social_spambots_1.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('social_spambots_1.csv', 'E13_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('social_spambots_1.csv', 'FSF_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('social_spambots_1.csv', 'INT_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('social_spambots_1.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('social_spambots_3.csv', 'traditional_spambots_1.csv', 'E13_users.csv')
#
# indomain datasets: ('social_spambots_3.csv', 'traditional_spambots_1.csv', 'TFP_users.csv')
#
# indomain datasets: ('social_spambots_3.csv', 'traditional_spambots_2.csv', 'E13_users.csv')
#
# indomain datasets: ('social_spambots_3.csv', 'traditional_spambots_2.csv', 'TFP_users.csv')
#
# indomain datasets: ('social_spambots_3.csv', 'traditional_spambots_3.csv', 'E13_users.csv')
#
# indomain datasets: ('social_spambots_3.csv', 'traditional_spambots_3.csv', 'TFP_users.csv')
#
# indomain datasets: ('social_spambots_3.csv', 'traditional_spambots_4.csv', 'E13_users.csv')
#
# indomain datasets: ('social_spambots_3.csv', 'traditional_spambots_4.csv', 'TFP_users.csv')
#
# indomain datasets: ('social_spambots_3.csv', 'E13_users.csv', 'FSF_users.csv')
#
# indomain datasets: ('social_spambots_3.csv', 'E13_users.csv', 'INT_users.csv')
#
# indomain datasets: ('social_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('social_spambots_3.csv', 'E13_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('social_spambots_3.csv', 'FSF_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('social_spambots_3.csv', 'INT_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('social_spambots_3.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('traditional_spambots_1.csv', 'traditional_spambots_2.csv', 'E13_users.csv')
#
# indomain datasets: ('traditional_spambots_1.csv', 'traditional_spambots_2.csv', 'TFP_users.csv')
#
# indomain datasets: ('traditional_spambots_1.csv', 'traditional_spambots_3.csv', 'E13_users.csv')
#
# indomain datasets: ('traditional_spambots_1.csv', 'traditional_spambots_3.csv', 'TFP_users.csv')
#
# indomain datasets: ('traditional_spambots_1.csv', 'traditional_spambots_4.csv', 'E13_users.csv')
#
# indomain datasets: ('traditional_spambots_1.csv', 'traditional_spambots_4.csv', 'TFP_users.csv')
#
# indomain datasets: ('traditional_spambots_1.csv', 'E13_users.csv', 'FSF_users.csv')
#
# indomain datasets: ('traditional_spambots_1.csv', 'E13_users.csv', 'INT_users.csv')
#
# indomain datasets: ('traditional_spambots_1.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('traditional_spambots_1.csv', 'E13_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('traditional_spambots_1.csv', 'FSF_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('traditional_spambots_1.csv', 'INT_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('traditional_spambots_1.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv')
#
# indomain datasets: ('traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'TFP_users.csv')
#
# indomain datasets: ('traditional_spambots_2.csv', 'traditional_spambots_4.csv', 'E13_users.csv')
#
# indomain datasets: ('traditional_spambots_2.csv', 'traditional_spambots_4.csv', 'TFP_users.csv')
#
# indomain datasets: ('traditional_spambots_2.csv', 'E13_users.csv', 'FSF_users.csv')
#
# indomain datasets: ('traditional_spambots_2.csv', 'E13_users.csv', 'INT_users.csv')
#
# indomain datasets: ('traditional_spambots_2.csv', 'E13_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('traditional_spambots_2.csv', 'FSF_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('traditional_spambots_2.csv', 'INT_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('traditional_spambots_2.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('traditional_spambots_3.csv', 'traditional_spambots_4.csv', 'E13_users.csv')
#
# indomain datasets: ('traditional_spambots_3.csv', 'traditional_spambots_4.csv', 'TFP_users.csv')
#
# indomain datasets: ('traditional_spambots_3.csv', 'E13_users.csv', 'FSF_users.csv')
#
# indomain datasets: ('traditional_spambots_3.csv', 'E13_users.csv', 'INT_users.csv')
#
# indomain datasets: ('traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('traditional_spambots_3.csv', 'E13_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('traditional_spambots_3.csv', 'FSF_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('traditional_spambots_3.csv', 'INT_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('traditional_spambots_3.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('traditional_spambots_4.csv', 'E13_users.csv', 'FSF_users.csv')
#
# indomain datasets: ('traditional_spambots_4.csv', 'E13_users.csv', 'INT_users.csv')
#
# indomain datasets: ('traditional_spambots_4.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('traditional_spambots_4.csv', 'E13_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('traditional_spambots_4.csv', 'FSF_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('traditional_spambots_4.csv', 'INT_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('traditional_spambots_4.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('E13_users.csv', 'FSF_users.csv', 'INT_users.csv')
#
# indomain datasets: ('E13_users.csv', 'FSF_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('E13_users.csv', 'FSF_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('E13_users.csv', 'INT_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('E13_users.csv', 'INT_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('FSF_users.csv', 'INT_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('FSF_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('INT_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'gilani-2017.tsv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'varol-2017.new3')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'social_spambots_1.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'social_spambots_3.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'traditional_spambots_1.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'traditional_spambots_2.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'traditional_spambots_3.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'traditional_spambots_4.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'E13_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'FSF_users.csv')
#
# ...
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'traditional_spambots_1.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'traditional_spambots_1.csv', 'traditional_spambots_2.csv', 'traditional_spambots_4.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'traditional_spambots_1.csv', 'traditional_spambots_2.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'traditional_spambots_4.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'FSF_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'INT_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'traditional_spambots_2.csv', 'traditional_spambots_4.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'traditional_spambots_2.csv', 'E13_users.csv', 'FSF_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'varol-2017.new3', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_1.csv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_1.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_1.csv', 'traditional_spambots_2.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_4.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'E13_users.csv', 'FSF_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'traditional_spambots_1.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'traditional_spambots_4.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'FSF_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'varol-2017.new3', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_1.csv', 'social_spambots_3.csv', 'traditional_spambots_1.csv', 'traditional_spambots_2.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_1.csv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_1.csv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_1.csv', 'traditional_spambots_1.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_1.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_1.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_1.csv', 'traditional_spambots_2.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'traditional_spambots_4.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'FSF_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'INT_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_4.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_1.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'traditional_spambots_4.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'FSF_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_1.csv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_1.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_1.csv', 'traditional_spambots_2.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'traditional_spambots_1.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_1.csv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_1.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_1.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'traditional_spambots_4.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'FSF_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'INT_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('cresci-rtbust-2019.tsv', 'traditional_spambots_1.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('vendor-purchased-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'social_spambots_1.csv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'social_spambots_1.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_1.csv', 'traditional_spambots_2.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'traditional_spambots_1.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botwiki-2019.tsv', 'botometer-feedback-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_1.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'traditional_spambots_1.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'vendor-purchased-2019.tsv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'social_spambots_1.csv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_1.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'traditional_spambots_4.csv', 'E13_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'FSF_users.csv', 'TFP_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'cresci-rtbust-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')
#
# indomain datasets: ('botometer-feedback-2019.tsv', 'vendor-purchased-2019.tsv', 'social_spambots_3.csv', 'traditional_spambots_2.csv', 'traditional_spambots_3.csv', 'E13_users.csv', 'TFP_users.csv', 'TWT_users.csv')

# %%
grp = users_total.groupby("dataset")

for dataset,dataset_data in grp:
    df = dataset_data[dataset_data["label"] == "human"]
    df_bot = dataset_data[dataset_data["label"] == "bot"]
    print(f"{dataset},{len(dataset_data)},{len(df)},{len(df_bot)}")
# Out:
# E13_users.csv,1481,1481,0
# FSF_users.csv,1169,0,1169
# INT_users.csv,1337,0,1337
# TFP_users.csv,469,469,0
# TWT_users.csv,845,0,845
# botometer-feedback-2019.tsv,461,350,111
# botwiki-2019.tsv,654,0,654
# celebrity-2019.tsv,5793,5793,0
# cresci-rtbust-2019.tsv,653,333,320
# cresci-stock-2018.tsv,13161,6166,6995
# fake_followers.csv,3351,0,3351
# genuine_accounts.csv,3474,3474,0
# gilani-2017.tsv,2491,1438,1053
# midterm-2018.tsv,7729,7687,42
# pronbots.tsv,1876,0,1876
# social_spambots_1.csv,991,0,991
# social_spambots_2.csv,3457,0,3457
# social_spambots_3.csv,464,0,464
# traditional_spambots_1.csv,1000,0,1000
# traditional_spambots_2.csv,100,0,100
# traditional_spambots_3.csv,403,0,403
# traditional_spambots_4.csv,1128,0,1128
# varol-2017.new3,2208,1520,688
# vendor-purchased-2019.tsv,736,0,736

# %%
df.head(5)
# Out:
# Empty DataFrame
# Columns: [dataset, label, profile_banner_url, id, id_str, name, screen_name, location, profile_location, description, url, protected, followers_count, friends_count, listed_count, favourites_count, utc_offset, time_zone, geo_enabled, verified, statuses_count, lang, contributors_enabled, is_translator, is_translation_enabled, profile_background_color, profile_background_image_url, profile_background_image_url_https, profile_background_tile, profile_image_url, profile_image_url_https, profile_link_color, profile_sidebar_border_color, profile_sidebar_fill_color, profile_text_color, profile_use_background_image, has_extended_profile, default_profile, default_profile_image, following, follow_request_sent, notifications, translator_type, created_at, dataset_grouped]
# Index: []
#
# [0 rows x 45 columns]
